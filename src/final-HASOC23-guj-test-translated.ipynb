# %%
# !pip install transformers
# !pip install torch
# Out:
# Collecting transformers
#   Downloading transformers-4.33.1-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 22.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.15.1 (from transformers)
#   Downloading huggingface_hub-0.17.1-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 23.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 48.9 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 50.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.17.1 safetensors-0.3.3 tokenizers-0.13.3 transformers-4.33.1
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df_guj = pd.read_csv('/content/gdrive/MyDrive/HASOC23/guj_train_translated_combined.csv', delimiter = ',')
df_guj
# Out:
#     tweet_id                 created_at  \
# 0     guj001  2023-05-19 15:44:55+00:00
# 1     guj002  2023-05-27 16:44:40+00:00
# 2     guj003  2023-05-25 03:56:05+00:00
# 3     guj004  2023-03-25 08:05:22+00:00
# 4     guj005  2023-05-24 07:01:42+00:00
# ..       ...                        ...
# 195   guj196  2023-03-25 16:10:38+00:00
# 196   guj197  2023-05-26 12:27:01+00:00
# 197   guj198  2023-05-27 07:26:02+00:00
# 198   guj199  2023-03-26 09:32:06+00:00
# 199   guj200  2023-05-23 13:30:01+00:00
#
#                                                   text user_screen_name label  \
# 0    @username @username ઇ વાયડાઈ ના તું હાઈસ ડોબો ...     Red__chilli_   HOF
# 1    @username @username આવા હલકા કેટલા છે કાય ખબર ...  sureshn25559831   HOF
# 2    @username @username તારી જેમ અમે જ્ઞાતિ માં બટ...      chattansinh   HOF
# 3    @username આવું વાહિયાત ખાવા વાળા લોકો પણ છે 😈😈...        imkpbhatt   NOT
# 4    @username @username બેશક, હું તમને મૂર્ખ કહી શ...     irshadvihari   NOT
# ..                                                 ...              ...   ...
# 195  @username આજ વિદેશી પ્રિન્ટ મીડિયા માં રાહુલ ગ...   nitinchavda548   NOT
# 196  @username @username @username ભડવો નયન ચાદર મો...      chattansinh   HOF
# 197  @username ચોદીના તારા જેવા ને પાકિસ્તાન ભેગી ન...      Rana_Naidu_   HOF
# 198  @username @username @username @username @usern...       kkpatel852   NOT
# 199  પારકી પંચાત : નીતિન પટેલને કેમ ઉડી ગયો છે રસ? ...    Divya_Bhaskar   NOT
#
#                                             translated  \
# 0    @username @username e waydi na thou hes dobo\n...
# 1    @username @username does not know how much is ...
# 2    @username @username like you are not in the ca...
# 3    @username is also a fucking people.\n\n@userna...
# 4    @username @username Of course, I can call you ...
# ..                                                 ...
# 195  @username has written a lot of Rahul Gandhi in...
# 196                      @username @username @username
# 197  @username Chodina Tara and Pakistan Gathering ...
# 198  @username @username @username @username @usern...
# 199  Parki Panchayat: Why is Nitin Patel flying?Yaj...
#
#                                               combined
# 0    @username @username ઇ વાયડાઈ ના તું હાઈસ ડોબો ...
# 1    @username @username આવા હલકા કેટલા છે કાય ખબર ...
# 2    @username @username તારી જેમ અમે જ્ઞાતિ માં બટ...
# 3    @username આવું વાહિયાત ખાવા વાળા લોકો પણ છે 😈😈...
# 4    @username @username બેશક, હું તમને મૂર્ખ કહી શ...
# ..                                                 ...
# 195  @username આજ વિદેશી પ્રિન્ટ મીડિયા માં રાહુલ ગ...
# 196  @username @username @username ભડવો નયન ચાદર મો...
# 197  @username ચોદીના તારા જેવા ને પાકિસ્તાન ભેગી ન...
# 198  @username @username @username @username @usern...
# 199  પારકી પંચાત : નીતિન પટેલને કેમ ઉડી ગયો છે રસ? ...
#
# [200 rows x 7 columns]

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
import torch
from transformers import BertModel, BertTokenizerFast


tokenizer = BertTokenizerFast.from_pretrained("setu4993/LaBSE")
if tokenizer.pad_token is None:
  print('adding token')
  tokenizer.add_special_tokens({'pad_token': '[PAD]'})
#bertmodel = BertModel.from_pretrained("setu4993/LaBSE")
#bertmodel.resize_token_embeddings(len(tokenizer))
#bertmodel.eval()
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/367 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/5.22M [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/13.6M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
from transformers import BertModel
from torch import nn
class CustomBERTModel(nn.Module):
    def __init__(self, model):
          super(CustomBERTModel, self).__init__()
          self.bert = model
          ### New layers:

          self.linear1 = nn.Linear(768, 512)
          self.dropout = nn.Dropout(0.3)
          self.relu = nn.LeakyReLU(negative_slope=0.01)
          self.linear2 = nn.Linear(512, 256)


          self.linear3 = nn.Linear(256, 128)


          self.linear4 = nn.Linear(128, 1) ## 2 classes in this example
          self.sigmoid = nn.Sigmoid()

    def forward(self, input_ids, attention_mask):
          output = self.bert(
               input_ids,
               attention_mask=attention_mask)
          #print(output)
          pooler_output = output['pooler_output']
          #print(sequence_output.shape())
          # sequence_output has the following shape: (batch_size, sequence_length, 768)
          linear1_output = self.linear1(pooler_output)
          relu1_output = self.relu(linear1_output)
          dropout1_output = self.dropout(relu1_output)

          linear2_output = self.linear2(dropout1_output)
          relu2_output = self.relu(linear2_output)


          linear3_output = self.linear3(relu2_output)
          relu3_output = self.relu(linear3_output)

          #sigmoid_output = self.sigmoid(linear2_output)

          linear4_output = self.linear4(relu3_output)
          sigmoid_output = self.sigmoid(linear4_output)
          return sigmoid_output

# %%
from transformers import BertModel
from torch import nn
class CustomBERTModel(nn.Module):
    def __init__(self, model):
          super(CustomBERTModel, self).__init__()
          self.bert = model
          ### New layers:
          self.dropout = nn.Dropout(0.3)
          self.linear1 = nn.Linear(768, 256)
          self.relu = nn.LeakyReLU(negative_slope=0.01)
          self.linear2 = nn.Linear(256, 1) ## 2 is the number of classes in this example
          self.sigmoid = nn.Sigmoid()

    def forward(self, input_ids, attention_mask):
          output = self.bert(
               input_ids,
               attention_mask=attention_mask)
          #print(output)
          pooler_output = self.dropout(output['pooler_output'])
          #print(sequence_output.shape())
          # sequence_output has the following shape: (batch_size, sequence_length, 768)
          linear1_output = self.linear1(pooler_output) ## extract the 1st token's embeddings
          relu_output = self.relu(linear1_output)
          linear2_output = self.linear2(relu_output)
          sigmoid_output = self.sigmoid(linear2_output)

          return sigmoid_output

# %%
import pandas as pd
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
class sinhalese_data(Dataset):
  def __init__(self, df_sinh, tokenizer):
    self.dataset = df_sinh
    self.data = list(self.dataset.combined)
    self.labels = list(self.dataset.label)
    self.tokenizer = tokenizer
    #model = BertModel.from_pretrained("setu4993/LaBSE")

  def __len__(self):
    return len(self.data)
  def __getitem__(self, index):
    example = self.data[index]
    inputs = tokenizer(example, return_tensors="pt", padding='max_length', max_length=512, truncation=True)
    input_ids = inputs['input_ids'].squeeze()
    attention_mask = inputs['attention_mask'].squeeze()
    #print(self.labels[index])
    labels = self.labels[index]
    return input_ids, attention_mask, labels

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %%
from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df_guj, test_size=0.15, stratify = df_guj['label'], random_state=42)

# %%
df_test
# Out:
#     tweet_id                 created_at  \
# 164   guj165  2023-05-24 15:35:30+00:00
# 71    guj072  2023-05-26 08:52:15+00:00
# 2     guj003  2023-05-25 03:56:05+00:00
# 72    guj073  2023-05-26 09:45:01+00:00
# 14    guj015  2023-05-24 07:03:09+00:00
# 148   guj149  2023-05-19 05:20:55+00:00
# 83    guj084  2023-05-28 06:30:00+00:00
# 12    guj013  2023-05-19 06:46:15+00:00
# 69    guj070  2023-05-21 06:33:53+00:00
# 195   guj196  2023-03-25 16:10:38+00:00
# 171   guj172  2023-05-23 05:26:08+00:00
# 120   guj121  2023-05-28 02:53:57+00:00
# 56    guj057  2023-03-26 01:27:44+00:00
# 180   guj181  2023-05-26 13:20:15+00:00
# 39    guj040  2023-05-28 07:22:44+00:00
# 162   guj163  2023-03-25 17:37:02+00:00
# 191   guj192  2023-05-23 05:09:02+00:00
# 142   guj143  2023-05-23 04:49:28+00:00
# 40    guj041  2023-05-19 14:29:20+00:00
# 100   guj101  2023-05-19 09:06:39+00:00
# 22    guj023  2023-05-20 05:40:08+00:00
# 144   guj145  2023-05-22 12:54:10+00:00
# 8     guj009  2023-05-26 20:14:27+00:00
# 96    guj097  2023-03-25 08:44:02+00:00
# 181   guj182  2023-05-28 08:18:34+00:00
# 170   guj171  2023-05-20 13:45:08+00:00
# 101   guj102  2023-05-20 14:46:35+00:00
# 141   guj142  2023-05-21 10:11:58+00:00
# 26    guj027  2023-05-20 01:43:42+00:00
# 43    guj044  2023-05-28 03:47:52+00:00
#
#                                                   text user_screen_name label  \
# 164  તેલના ડબ્બા નાં ભાવ ઘટવાનું શરૂ થયુ છે\n\nકોંગ...        RWGujarat   HOF
# 71   @username @username Gujarat નું અપમાન તો કોંગ્...        raj869180   NOT
# 2    @username @username તારી જેમ અમે જ્ઞાતિ માં બટ...      chattansinh   HOF
# 72   @username @username @username 9 વર્ષ મા ઉદ્યોગ...   AshokBabariya8   NOT
# 14   ગુજરાત માં ભરૂચ જિલ્લામાં આવેલો જંબુસર તાલુકામ...  PinalPa10542589   NOT
# 148  @username વિરાટ હિન્દુ ને ગઈ રાત નોં ઉજાગરો સે...     Are_O_Sambha   HOF
# 83   પારકી પંચાત' - જુઓ સોમ થી શનિ બપોરે 3 વાગ્યે. ...    Divya_Bhaskar   NOT
# 12   @username @username આ હું તો બોલીશ વાળા રોનક પ...         Amru1967   NOT
# 69   જુઢો એ કાળિયો કહે મુજ વગર એને કોઈ ના ફાવે.\nગો...    Mutradifalfaz   NOT
# 195  @username આજ વિદેશી પ્રિન્ટ મીડિયા માં રાહુલ ગ...   nitinchavda548   NOT
# 171  ચોકીદાર ને તમે ચોર, મૂર્ખો કહી શકો છો..\n🍊🍊🤣🤣 ...        the_wall9   HOF
# 120                              ટોટી ચોર હરામખોર @url  DhairyaMakwana7   HOF
# 56   @username @username MLA બનવા માં તો જમાનત જપ્ત...         wish4u23   NOT
# 180  આજ ઢોંગી ની રેલી છે ને?\nઆવા ઢોંગી મા તમે જો આ...   Mayur23_Oxygen   HOF
# 39   @username ગુજરાત માં ભરૂચ જિલ્લામાં આવેલો જંબુ...  PinalPa10542589   HOF
# 162  વિધાનસભાને 'ચોર મંડળ' કહેવા બદલ સંજય રાઉત વિરુ...        News18Guj   NOT
# 191  @username 🤔 ભ્રષ્ટાચારી કૌભાંડી ચોર લુખ્ખા અસા...     TGThakor2528   NOT
# 142  રાજકોટ: કસ્ટડીમાંથી ચોર ભાગવાનો મામલો\n\nલોકઅપ...        News18Guj   NOT
# 40                       @username @username નવરી બજાર          ankitnp   HOF
# 100  @username @username ગુજરાત સરકાર ની વાક નથી વા...      imaandaar94   HOF
# 22   @username ઇમા રેલવે ના  પાટા પર જઈને પંચાત કરવ...  DhavalS16030050   NOT
# 144  @username @username @username @username એલા આ ...      chattansinh   HOF
# 8    @username  સાહેબ શ્રી જુનાગઢ જિલ્લા નાં માંગરો...       SutharAdil   NOT
# 96   @username @username @username @username @usern...    Mulik52779427   NOT
# 181  @username @username @username બાયડી નો ભાઇ આયવ...  Arvind_khejdiwa   HOF
# 170  @username શીંગડા વગરનો બળદ....અભણ કેજરી ને શું...        patelvs05   HOF
# 101  @username ચોર ના ભાઇ ઘંટી ચોર ,કાળુંધન બધું સો...  mineshp26682481   HOF
# 141  રાજકોટ: પોલીસ કસ્ટડીમાંથી ચોર ફરાર, પાઈપથી નીચ...        News18Guj   NOT
# 26   @username ઢોંગી બાબા માઈન્ડ રીડિંગ નો ઉપયોગ કર...  AshokCh25905849   HOF
# 43   @username @username @username આને મુકો આ નવરી ...  ManishD66520134   HOF
#
#                                             translated  \
# 164  The price of oil bins has begun to fall\n\nIf ...
# 71   @username @username Gujarat insults Congress e...
# 2    @username @username like you are not in the ca...
# 72   @username @username @username businessmen in 9...
# 14   In Jambusar taluka in Bharuch district in Guja...
# 148      @username Virat Hindu to light last night ...
# 83   Parki Panchayat ' - See Mon to Saturday at 3pm...
# 12   @username @username.\nThe program is not compl...
# 69   The knife does not say no one without me.\nHow...
# 195  @username has written a lot of Rahul Gandhi in...
# 171  You can call the watchman a thief, fool.\n🍊🍊🤣🤣...
# 120                           Cock thief harassed @url
# 56   @username @username MLA has been confiscated, ...
# 180  This is a rally of hypocrisy, isn't it?\nIf yo...
# 39   @username in Jambusar taluka in Bharuch distri...
# 162  Sanjay Raut's notice of breach of privilege la...
# 191  @username 🤔 Corruption scandal thief loud anti...
# 142  Rajkot: A thief's case of custody\n\nA thief e...
# 40                    @username @username Navari Bazar
# 100  @username @username is not the word of the Gov...
# 22   Where did the @username go to the railway trac...
# 144  @username @username @username @username Ella T...
# 8    @username Saheb Lights are often gone in the M...
# 96   @username @username @username @username @usern...
# 181  @username @username @username Biddy's brother Avo
# 170  @username hornless ox .... What does an illite...
# 101  The @username thief's brother bell thief, blac...
# 141  Rajkot: A thief absconding from police custody...
# 26   @username is fooling people using hypocritical...
# 43   @username @username @username This is the Nava...
#
#                                               combined
# 164  તેલના ડબ્બા નાં ભાવ ઘટવાનું શરૂ થયુ છે\n\nકોંગ...
# 71   @username @username Gujarat નું અપમાન તો કોંગ્...
# 2    @username @username તારી જેમ અમે જ્ઞાતિ માં બટ...
# 72   @username @username @username 9 વર્ષ મા ઉદ્યોગ...
# 14   ગુજરાત માં ભરૂચ જિલ્લામાં આવેલો જંબુસર તાલુકામ...
# 148  @username વિરાટ હિન્દુ ને ગઈ રાત નોં ઉજાગરો સે...
# 83   પારકી પંચાત' - જુઓ સોમ થી શનિ બપોરે 3 વાગ્યે. ...
# 12   @username @username આ હું તો બોલીશ વાળા રોનક પ...
# 69   જુઢો એ કાળિયો કહે મુજ વગર એને કોઈ ના ફાવે.\nગો...
# 195  @username આજ વિદેશી પ્રિન્ટ મીડિયા માં રાહુલ ગ...
# 171  ચોકીદાર ને તમે ચોર, મૂર્ખો કહી શકો છો..\n🍊🍊🤣🤣 ...
# 120     ટોટી ચોર હરામખોર @url Cock thief harassed @url
# 56   @username @username MLA બનવા માં તો જમાનત જપ્ત...
# 180  આજ ઢોંગી ની રેલી છે ને?\nઆવા ઢોંગી મા તમે જો આ...
# 39   @username ગુજરાત માં ભરૂચ જિલ્લામાં આવેલો જંબુ...
# 162  વિધાનસભાને 'ચોર મંડળ' કહેવા બદલ સંજય રાઉત વિરુ...
# 191  @username 🤔 ભ્રષ્ટાચારી કૌભાંડી ચોર લુખ્ખા અસા...
# 142  રાજકોટ: કસ્ટડીમાંથી ચોર ભાગવાનો મામલો\n\nલોકઅપ...
# 40   @username @username નવરી બજાર @username @usern...
# 100  @username @username ગુજરાત સરકાર ની વાક નથી વા...
# 22   @username ઇમા રેલવે ના  પાટા પર જઈને પંચાત કરવ...
# 144  @username @username @username @username એલા આ ...
# 8    @username  સાહેબ શ્રી જુનાગઢ જિલ્લા નાં માંગરો...
# 96   @username @username @username @username @usern...
# 181  @username @username @username બાયડી નો ભાઇ આયવ...
# 170  @username શીંગડા વગરનો બળદ....અભણ કેજરી ને શું...
# 101  @username ચોર ના ભાઇ ઘંટી ચોર ,કાળુંધન બધું સો...
# 141  રાજકોટ: પોલીસ કસ્ટડીમાંથી ચોર ફરાર, પાઈપથી નીચ...
# 26   @username ઢોંગી બાબા માઈન્ડ રીડિંગ નો ઉપયોગ કર...
# 43   @username @username @username આને મુકો આ નવરી ...

# %%
model = torch.load('/content/gdrive/MyDrive/saved_models/last-LA-BSE-Sigmoid-deep-translated-5ep-guj',map_location=torch.device('cpu'))
model.eval()
model.to(device)
# Out:
# CustomBERTModel(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(501153, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.3, inplace=False)
#   (linear1): Linear(in_features=768, out_features=256, bias=True)
#   (relu): LeakyReLU(negative_slope=0.01)
#   (linear2): Linear(in_features=256, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
dataset = sinhalese_data(df_test, tokenizer)

# %%
len(df_test[df_test['label']==1])
# Out:
# 0

# %%
import torch
from torch.nn import functional as F

optimizer = torch.optim.AdamW(model.parameters(), lr=2e-5)
loss_fn = torch.nn.BCELoss()
batch_size = 4
num_epochs = 10
data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %%
#inputs = tokenizer(example, return_tensors="pt", padding='max_length', max_length=512, truncation=True)
'''total_loss = 0
criterion = nn.BCELoss()
dataset_test = sinhalese_data(df_test, tokenizer)
data_loader = DataLoader(dataset_test, batch_size=batch_size, shuffle=True)
for batch in data_loader:
        # Move batch tensors to the device
        input_ids = batch[0].to(device)
        attention_mask = batch[1].to(device)
        labels_lst = batch[2].to(device)
        labels = labels_lst.reshape(len(labels_lst),1)
        labels = labels.float()
        # Zero the gradients


        # Forward pass
        outputs = model(input_ids=input_ids,attention_mask = attention_mask)
               #print(outputs)
        #outputs = F.sigmoid(outputs)
       #print(outputs.shape, labels.shape)
        #print('Output: ', outputs, '\nLabels: ', labels)
        print('outputs:', outputs)
        print('\n')
        print('label:', labels.reshape(len(labels_lst),1))
        loss = criterion(outputs, labels.reshape(len(labels_lst),1))
        print('loss: ',loss)
        #print(loss)
        # Backward pass and optimization
        #loss.backward()
        #optimizer.step()

        total_loss += loss.item()/len(labels_lst)
        print('loss: ', total_loss)

avg_loss = total_loss / len(data_loader)
print(f"Average Loss: {avg_loss:.4f}")'''
pass

# %%
#labels_arr = []

dataset_test = sinhalese_data(df_test, tokenizer)
data_loader = DataLoader(dataset_test, batch_size=batch_size, shuffle=True)
count = 0
correct = 0
for batch in data_loader:
        # Move batch tensors to the device
        input_ids = batch[0].to(device)
        attention_mask = batch[1].to(device)
        labels_lst = batch[2].to(device)
        labels = labels_lst.reshape(len(labels_lst),1)
        labels = labels.float()
        # Zero the gradients


        # Forward pass
        outputs = model(input_ids=input_ids,attention_mask = attention_mask)
        predictions = outputs.tolist()
        #print(predictions)
        for i in range(len(predictions)):
            predictions[i] = round(predictions[i][0])
        print(predictions)
        labels_lst = labels.tolist()

        for j in range(len(labels_lst)):
          labels_lst[j] = int(labels_lst[j][0])
        print(labels_lst)

        for k in range(len(labels_lst)):
          if labels_lst[k]==predictions[k]:
            correct+=1

          count+=1

        print(f'Performance: {correct}/{count}')


print(f'Accuracy: {(correct/count)*100}%')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-0f0b8957edb1> in <cell line: 7>()
#       9         input_ids = batch[0].to(device)
#      10         attention_mask = batch[1].to(device)
# ---> 11         labels_lst = batch[2].to(device)
#      12         labels = labels_lst.reshape(len(labels_lst),1)
#      13         labels = labels.float()
#
# AttributeError: 'tuple' object has no attribute 'to'
