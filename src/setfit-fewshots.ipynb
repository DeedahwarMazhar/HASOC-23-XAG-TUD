# %%
# !pip install transformers
# !pip install torch
# !pip install setfit
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.31.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.3.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: setfit in /usr/local/lib/python3.10/dist-packages (0.7.0)
# Requirement already satisfied: datasets>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from setfit) (2.14.4)
# Requirement already satisfied: sentence-transformers>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from setfit) (2.2.2)
# Requirement already satisfied: evaluate>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from setfit) (0.4.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (9.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (3.3.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (0.70.15)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (3.8.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (0.16.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (6.0.1)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from evaluate>=0.3.0->setfit) (0.18.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (4.31.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (0.15.2+cu118)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (0.1.99)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets>=2.3.0->setfit) (3.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets>=2.3.0->setfit) (4.7.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.3.0->setfit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.3.0->setfit) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.3.0->setfit) (2023.7.22)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.1->setfit) (2023.6.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.1->setfit) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.1->setfit) (0.3.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=2.2.1->setfit) (8.1.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=2.2.1->setfit) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.3.0->setfit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.3.0->setfit) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers>=2.2.1->setfit) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=2.2.1->setfit) (9.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets>=2.3.0->setfit) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (1.3.0)

# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df_guj = pd.read_csv('/content/gdrive/MyDrive/HASOC23/guj_train_translated_combined.csv', delimiter = ',')
df_guj
# Out:
#     tweet_id                 created_at  \
# 0     guj001  2023-05-19 15:44:55+00:00
# 1     guj002  2023-05-27 16:44:40+00:00
# 2     guj003  2023-05-25 03:56:05+00:00
# 3     guj004  2023-03-25 08:05:22+00:00
# 4     guj005  2023-05-24 07:01:42+00:00
# ..       ...                        ...
# 195   guj196  2023-03-25 16:10:38+00:00
# 196   guj197  2023-05-26 12:27:01+00:00
# 197   guj198  2023-05-27 07:26:02+00:00
# 198   guj199  2023-03-26 09:32:06+00:00
# 199   guj200  2023-05-23 13:30:01+00:00
#
#                                                   text user_screen_name label  \
# 0    @username @username ઇ વાયડાઈ ના તું હાઈસ ડોબો ...     Red__chilli_   HOF
# 1    @username @username આવા હલકા કેટલા છે કાય ખબર ...  sureshn25559831   HOF
# 2    @username @username તારી જેમ અમે જ્ઞાતિ માં બટ...      chattansinh   HOF
# 3    @username આવું વાહિયાત ખાવા વાળા લોકો પણ છે 😈😈...        imkpbhatt   NOT
# 4    @username @username બેશક, હું તમને મૂર્ખ કહી શ...     irshadvihari   NOT
# ..                                                 ...              ...   ...
# 195  @username આજ વિદેશી પ્રિન્ટ મીડિયા માં રાહુલ ગ...   nitinchavda548   NOT
# 196  @username @username @username ભડવો નયન ચાદર મો...      chattansinh   HOF
# 197  @username ચોદીના તારા જેવા ને પાકિસ્તાન ભેગી ન...      Rana_Naidu_   HOF
# 198  @username @username @username @username @usern...       kkpatel852   NOT
# 199  પારકી પંચાત : નીતિન પટેલને કેમ ઉડી ગયો છે રસ? ...    Divya_Bhaskar   NOT
#
#                                             translated  \
# 0    @username @username e waydi na thou hes dobo\n...
# 1    @username @username does not know how much is ...
# 2    @username @username like you are not in the ca...
# 3    @username is also a fucking people.\n\n@userna...
# 4    @username @username Of course, I can call you ...
# ..                                                 ...
# 195  @username has written a lot of Rahul Gandhi in...
# 196                      @username @username @username
# 197  @username Chodina Tara and Pakistan Gathering ...
# 198  @username @username @username @username @usern...
# 199  Parki Panchayat: Why is Nitin Patel flying?Yaj...
#
#                                               combined
# 0    @username @username ઇ વાયડાઈ ના તું હાઈસ ડોબો ...
# 1    @username @username આવા હલકા કેટલા છે કાય ખબર ...
# 2    @username @username તારી જેમ અમે જ્ઞાતિ માં બટ...
# 3    @username આવું વાહિયાત ખાવા વાળા લોકો પણ છે 😈😈...
# 4    @username @username બેશક, હું તમને મૂર્ખ કહી શ...
# ..                                                 ...
# 195  @username આજ વિદેશી પ્રિન્ટ મીડિયા માં રાહુલ ગ...
# 196  @username @username @username ભડવો નયન ચાદર મો...
# 197  @username ચોદીના તારા જેવા ને પાકિસ્તાન ભેગી ન...
# 198  @username @username @username @username @usern...
# 199  પારકી પંચાત : નીતિન પટેલને કેમ ઉડી ગયો છે રસ? ...
#
# [200 rows x 7 columns]

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df_guj['label'] = le.fit_transform(df_guj.label.values)
df_guj
# Out:
#     tweet_id                 created_at  \
# 0     guj001  2023-05-19 15:44:55+00:00
# 1     guj002  2023-05-27 16:44:40+00:00
# 2     guj003  2023-05-25 03:56:05+00:00
# 3     guj004  2023-03-25 08:05:22+00:00
# 4     guj005  2023-05-24 07:01:42+00:00
# ..       ...                        ...
# 195   guj196  2023-03-25 16:10:38+00:00
# 196   guj197  2023-05-26 12:27:01+00:00
# 197   guj198  2023-05-27 07:26:02+00:00
# 198   guj199  2023-03-26 09:32:06+00:00
# 199   guj200  2023-05-23 13:30:01+00:00
#
#                                                   text user_screen_name  \
# 0    @username @username ઇ વાયડાઈ ના તું હાઈસ ડોબો ...     Red__chilli_
# 1    @username @username આવા હલકા કેટલા છે કાય ખબર ...  sureshn25559831
# 2    @username @username તારી જેમ અમે જ્ઞાતિ માં બટ...      chattansinh
# 3    @username આવું વાહિયાત ખાવા વાળા લોકો પણ છે 😈😈...        imkpbhatt
# 4    @username @username બેશક, હું તમને મૂર્ખ કહી શ...     irshadvihari
# ..                                                 ...              ...
# 195  @username આજ વિદેશી પ્રિન્ટ મીડિયા માં રાહુલ ગ...   nitinchavda548
# 196  @username @username @username ભડવો નયન ચાદર મો...      chattansinh
# 197  @username ચોદીના તારા જેવા ને પાકિસ્તાન ભેગી ન...      Rana_Naidu_
# 198  @username @username @username @username @usern...       kkpatel852
# 199  પારકી પંચાત : નીતિન પટેલને કેમ ઉડી ગયો છે રસ? ...    Divya_Bhaskar
#
#      label                                         translated  \
# 0        0  @username @username e waydi na thou hes dobo\n...
# 1        0  @username @username does not know how much is ...
# 2        0  @username @username like you are not in the ca...
# 3        1  @username is also a fucking people.\n\n@userna...
# 4        1  @username @username Of course, I can call you ...
# ..     ...                                                ...
# 195      1  @username has written a lot of Rahul Gandhi in...
# 196      0                      @username @username @username
# 197      0  @username Chodina Tara and Pakistan Gathering ...
# 198      1  @username @username @username @username @usern...
# 199      1  Parki Panchayat: Why is Nitin Patel flying?Yaj...
#
#                                               combined
# 0    @username @username ઇ વાયડાઈ ના તું હાઈસ ડોબો ...
# 1    @username @username આવા હલકા કેટલા છે કાય ખબર ...
# 2    @username @username તારી જેમ અમે જ્ઞાતિ માં બટ...
# 3    @username આવું વાહિયાત ખાવા વાળા લોકો પણ છે 😈😈...
# 4    @username @username બેશક, હું તમને મૂર્ખ કહી શ...
# ..                                                 ...
# 195  @username આજ વિદેશી પ્રિન્ટ મીડિયા માં રાહુલ ગ...
# 196  @username @username @username ભડવો નયન ચાદર મો...
# 197  @username ચોદીના તારા જેવા ને પાકિસ્તાન ભેગી ન...
# 198  @username @username @username @username @usern...
# 199  પારકી પંચાત : નીતિન પટેલને કેમ ઉડી ગયો છે રસ? ...
#
# [200 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

df_train, df_val = train_test_split(df_guj, test_size=0.15, stratify = df_guj['label'], random_state=42)

# %%
from datasets import load_dataset
from sentence_transformers.losses import CosineSimilarityLoss
import datasets
from setfit import SetFitModel, SetFitTrainer, sample_dataset

train_dataset = datasets.Dataset.from_dict(df_train)
test_dataset = datasets.Dataset.from_dict(df_val)
my_dataset_dict = datasets.DatasetDict({"train":train_dataset,"val":test_dataset})

# %%
my_dataset_dict
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['tweet_id', 'created_at', 'text', 'user_screen_name', 'label', 'translated', 'combined'],
#         num_rows: 170
#     })
#     val: Dataset({
#         features: ['tweet_id', 'created_at', 'text', 'user_screen_name', 'label', 'translated', 'combined'],
#         num_rows: 30
#     })
# })

# %%
from transformers import BertModel
from torch import nn
class CustomBERTModel(nn.Module):
    def __init__(self, model):
          super(CustomBERTModel, self).__init__()
          self.bert = model
          ### New layers:
          self.dropout = nn.Dropout(0.3)
          self.linear1 = nn.Linear(768, 256)
          self.relu = nn.LeakyReLU(negative_slope=0.01)
          self.linear2 = nn.Linear(256, 1) ## 2 is the number of classes in this example
          self.sigmoid = nn.Sigmoid()

    def forward(self, input_ids, attention_mask):
          output = self.bert(
               input_ids,
               attention_mask=attention_mask)
          #print(output)
          pooler_output = self.dropout(output['pooler_output'])
          #print(sequence_output.shape())
          # sequence_output has the following shape: (batch_size, sequence_length, 768)
          linear1_output = self.linear1(pooler_output) ## extract the 1st token's embeddings
          relu_output = self.relu(linear1_output)
          linear2_output = self.linear2(relu_output)
          sigmoid_output = self.sigmoid(linear2_output)

          return sigmoid_output

# %%
'''import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
model = torch.load('/content/gdrive/MyDrive/saved_models/FSL-LA-BSE-Sigmoid-deep-translated-7ep-guj',map_location=torch.device('cpu'))
model.eval()
model.to(device)'''
pass

# %%
from sentence_transformers.losses import CosineSimilarityLoss

from setfit import SetFitModel, SetFitTrainer, sample_dataset


# Load a dataset from the Hugging Face Hub


# Simulate the few-shot regime by sampling 8 examples per class
train_dataset = sample_dataset(my_dataset_dict['train'], label_column="label", num_samples=64)
eval_dataset = my_dataset_dict['val']
#print(train_dataset)
#print(train_dataset['combined'])
# Load a SetFit model from Hub
model = SetFitModel.from_pretrained("sentence-transformers/LaBSE") #tsdea
model.fit(train_dataset['combined'],train_dataset['label'], num_epochs=7)

# Create trainer
trainer = SetFitTrainer(
    model=model,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    loss_class=CosineSimilarityLoss,
    metric="accuracy",
    batch_size=32,
    num_iterations=20, # The number of text pairs to generate for contrastive learning
    num_epochs=1, # The number of epochs to use for contrastive learning
    column_mapping={"combined": "text", "label": "label"} # Map dataset columns to text/label expected by trainer
)

# Train and evaluate
trainer.train()
metrics = trainer.evaluate()
# Out:
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 3458907e-e97b-43f5-924f-13fca4087f10)')' thrown while requesting HEAD https://huggingface.co/sentence-transformers/LaBSE/resolve/main/config.json
# WARNING:huggingface_hub.utils._http:'(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 3458907e-e97b-43f5-924f-13fca4087f10)')' thrown while requesting HEAD https://huggingface.co/sentence-transformers/LaBSE/resolve/main/config.json
# model_head.pkl not found on HuggingFace Hub, initialising classification head with random weights. You should TRAIN this model on a downstream task to use it for predictions and inference.
# Applying column mapping to training dataset
# Generating Training Pairs:   0%|          | 0/20 [00:00<?, ?it/s]
# ***** Running training *****
#   Num examples = 5120
#   Num epochs = 1
#   Total optimization steps = 160
#   Total train batch size = 32
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/160 [00:00<?, ?it/s]
# Applying column mapping to evaluation dataset
# ***** Running evaluation *****

# %%
metrics
# Out:
# {'accuracy': 0.7333333333333333}
